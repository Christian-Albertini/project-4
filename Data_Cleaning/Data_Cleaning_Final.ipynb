# %%
import pandas as pd
import numpy as np
import random

# %%
final_data=pd.read_csv("../Resources/Merged_Stats.csv")

# %%
final_data.head(15)
# Out:
#     Unnamed: 0        Player  Season Team League  Games_Played  All-Star  \
# 0            1   Adam Duvall    2023  BOS     AL            92         0
# 1            2   Adam Duvall    2023  BOS     AL            92         0
# 2            3   Adam Duvall    2023  BOS     AL            92         0
# 3            4   Adam Duvall    2023  BOS     AL            92         0
# 4            5   Adam Duvall    2023  BOS     AL            92         0
# 5            6   Adam Duvall    2023  BOS     AL            92         0
# 6            7   Adam Duvall    2023  BOS     AL            92         0
# 7            8   Adam Duvall    2023  BOS     AL            92         0
# 8            9  Adam Frazier    2023  BAL     AL           141         0
# 9           10  Adam Frazier    2023  BAL     AL           141         0
# 10          11  Adam Frazier    2023  BAL     AL           141         0
# 11          12  Adam Frazier    2023  BAL     AL           141         0
# ...

# %%
final_data_cleaned=final_data.drop(columns=['Team', 'Single','Double','Triple','Caught_Stealing', 'League'])
final_data_cleaned.head()
# Out:
#    Unnamed: 0       Player  Season  Games_Played  All-Star  Plate_Appearances  \
# 0           1  Adam Duvall    2023            92         0                353
# 1           2  Adam Duvall    2023            92         0                353
# 2           3  Adam Duvall    2023            92         0                353
# 3           4  Adam Duvall    2023            92         0                353
# 4           5  Adam Duvall    2023            92         0                353
#
#    At_Bats  Runs  Hits  Home_Run  ...  Stolen_Bases  Walks  Strikeouts  \
# 0      320    45    79        21  ...             4     22         110
# 1      320    45    79        21  ...             4     22         110
# 2      320    45    79        21  ...             4     22         110
# 3      320    45    79        21  ...             4     22         110
# 4      320    45    79        21  ...             4     22         110
#
#    Bating_Average  On_Base_Percentage  Slugging_Percentage  \
# ...

# %%
final_data_cleaned=final_data_cleaned.drop(columns=['Player'])
final_data_cleaned.head()

# %%
final_data_cleaned=final_data_cleaned.dropna()
final_data_cleaned=final_data_cleaned.drop_duplicates()

# %%
final_data_cleaned.to_csv("../Resources/Merged_Stats_Cleaned.csv", index=False)
