# %%
# Import dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
import tensorflow as tf
import numpy as np



# Use raw URLs from GitHub
combined_url = 'https://raw.githubusercontent.com/Christian-Albertini/project-4/main/Resources/Combined_Player_Stats_Cleaned_3.csv'

# Read the CSV files
Combined_Player_Stats = pd.read_csv(combined_url)

# Display the first few rows of each DataFrame
Combined_Player_Stats.head()
# Out:
#    Season Team League  Games_Played  All-Star  Plate_Appearances  At_Bats  \
# 0    2023  BOS     AL            92         0                353      320
# 1    2023  BAL     AL           141         0                455      412
# 2    2023  BAL     AL           154         1                687      588
# 3    2023  TEX     AL           148         1                632      555
# 4    2023  DET     AL           112         0                357      312
#
#    Runs  Hits  Single  ...  Stolen_Bases  Caught_Stealing  Walks  Strikeouts  \
# 0    45    79      32  ...             4                0     22         110
# 1    59    99      63  ...            11                4     32          68
# 2    84   163     111  ...             1                2     92         101
# 3   108   136      68  ...             9                1     65         175
# 4    40    68      43  ...            14                3     42          89
#
#    Batting_Average  On_Base_Percentage  Slugging_Percentage  \
# 0            0.247               0.303                0.531
# 1            0.240               0.300                0.396
# 2            0.277               0.374                0.435
# 3            0.245               0.328                0.508
# 4            0.218               0.310                0.372
#
#    On_Base_Plus_Slugging_(OPS)  On_Base_Plus_Slugging_Plus_(OPS+)  Total_Bases
# 0                        0.834                                119          170
# 1                        0.696                                 94          163
# 2                        0.809                                128          256
# 3                        0.836                                127          282
# 4                        0.682                                 88          116
#
# [5 rows x 24 columns]

# %%
# Convert categorical data to numeric
combined_df = pd.get_dummies(Combined_Player_Stats, columns=['League', 'Team'])

# Review Dataframes
combined_df.head()
# Out:
#    Season  Games_Played  All-Star  Plate_Appearances  At_Bats  Runs  Hits  \
# 0    2023            92         0                353      320    45    79
# 1    2023           141         0                455      412    59    99
# 2    2023           154         1                687      588    84   163
# 3    2023           148         1                632      555   108   136
# 4    2023           112         0                357      312    40    68
#
#    Single  Double  Triple  ...  Team_PHI  Team_PIT  Team_SDP  Team_SEA  \
# 0      32      24       2  ...     False     False     False     False
# 1      63      21       2  ...     False     False     False     False
# 2     111      31       1  ...     False     False     False     False
# 3      68      29       0  ...     False     False     False     False
# 4      43      13       1  ...     False     False     False     False
#
#    Team_SFG  Team_STL  Team_TBR  Team_TEX  Team_TOR  Team_WSN
# 0     False     False     False     False     False     False
# 1     False     False     False     False     False     False
# 2     False     False     False     False     False     False
# 3     False     False     False      True     False     False
# 4     False     False     False     False     False     False
#
# [5 rows x 54 columns]

# %%
# Identify feature and target arrays
y = combined_df['All-Star']
X = combined_df.drop(columns=['All-Star'])

# Split the data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit and scale the data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Apply SMOTE to balance the dataset
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# %%
# Compute class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_resampled),
    y=y_train_resampled
)
class_weight_dict = dict(enumerate(class_weights))

# Define model
number_input_features = len(X_train_resampled[0])
hidden_nodes_layer1 = 30
hidden_nodes_layer2 = 20
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='relu'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='relu'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(
    X_train_resampled, y_train_resampled,
    epochs=50,
    validation_split=0.2,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.6172 - loss: 0.6475 - val_accuracy: 0.7740 - val_loss: 0.5073
# Epoch 2/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8130 - loss: 0.4497 - val_accuracy: 0.7740 - val_loss: 0.5186
# Epoch 3/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8259 - loss: 0.3857 - val_accuracy: 0.8180 - val_loss: 0.4363
# Epoch 4/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8446 - loss: 0.3655 - val_accuracy: 0.8240 - val_loss: 0.4325
# Epoch 5/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8535 - loss: 0.3344 - val_accuracy: 0.8200 - val_loss: 0.4181
# Epoch 6/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8340 - loss: 0.3539 - val_accuracy: 0.8480 - val_loss: 0.3791
# Epoch 7/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8716 - loss: 0.3008 - val_accuracy: 0.8420 - val_loss: 0.3841
# Epoch 8/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8691 - loss: 0.2920 - val_accuracy: 0.8460 - val_loss: 0.3847
# Epoch 9/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8759 - loss: 0.2816 - val_accuracy: 0.8260 - val_loss: 0.4099
# Epoch 10/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8827 - loss: 0.2860 - val_accuracy: 0.8440 - val_loss: 0.3848
# Epoch 11/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8783 - loss: 0.2771 - val_accuracy: 0.8620 - val_loss: 0.3387
# Epoch 12/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8951 - loss: 0.2586 - val_accuracy: 0.8680 - val_loss: 0.3348
# Epoch 13/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8909 - loss: 0.2637 - val_accuracy: 0.8700 - val_loss: 0.3494
# Epoch 14/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.2372 - val_accuracy: 0.8660 - val_loss: 0.3515
# Epoch 15/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9162 - loss: 0.2176 - val_accuracy: 0.8640 - val_loss: 0.3320
# Epoch 16/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9229 - loss: 0.2066 - val_accuracy: 0.8860 - val_loss: 0.3002
# Epoch 17/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9105 - loss: 0.2051 - val_accuracy: 0.8900 - val_loss: 0.2650
# Epoch 18/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9180 - loss: 0.1876 - val_accuracy: 0.8760 - val_loss: 0.3202
# Epoch 19/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9351 - loss: 0.1821 - val_accuracy: 0.9060 - val_loss: 0.2454
# Epoch 20/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9162 - loss: 0.1953 - val_accuracy: 0.9080 - val_loss: 0.2407
# Epoch 21/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9480 - loss: 0.1506 - val_accuracy: 0.9380 - val_loss: 0.1861
# Epoch 22/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9430 - loss: 0.1617 - val_accuracy: 0.9200 - val_loss: 0.2103
# Epoch 23/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9496 - loss: 0.1373 - val_accuracy: 0.9220 - val_loss: 0.2015
# Epoch 24/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9535 - loss: 0.1338 - val_accuracy: 0.8880 - val_loss: 0.2719
# Epoch 25/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9455 - loss: 0.1494 - val_accuracy: 0.9260 - val_loss: 0.2143
# Epoch 26/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.1322 - val_accuracy: 0.9400 - val_loss: 0.2029
# Epoch 27/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.1027 - val_accuracy: 0.9520 - val_loss: 0.1818
# Epoch 28/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9611 - loss: 0.1175 - val_accuracy: 0.9620 - val_loss: 0.1502
# Epoch 29/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9661 - loss: 0.0976 - val_accuracy: 0.9620 - val_loss: 0.1571
# Epoch 30/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0928 - val_accuracy: 0.9480 - val_loss: 0.1544
# Epoch 31/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9778 - loss: 0.0817 - val_accuracy: 0.9560 - val_loss: 0.1565
# Epoch 32/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.0870 - val_accuracy: 0.9800 - val_loss: 0.0891
# Epoch 33/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9753 - loss: 0.0825 - val_accuracy: 0.9540 - val_loss: 0.1563
# Epoch 34/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9782 - loss: 0.0838 - val_accuracy: 0.9640 - val_loss: 0.1324
# Epoch 35/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9836 - loss: 0.0705 - val_accuracy: 0.9640 - val_loss: 0.1242
# Epoch 36/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9836 - loss: 0.0721 - val_accuracy: 0.9720 - val_loss: 0.0831
# Epoch 37/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.0625 - val_accuracy: 0.9560 - val_loss: 0.1289
# Epoch 38/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9835 - loss: 0.0628 - val_accuracy: 0.9740 - val_loss: 0.0861
# Epoch 39/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0491 - val_accuracy: 0.9720 - val_loss: 0.0686
# Epoch 40/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9858 - loss: 0.0537 - val_accuracy: 0.9740 - val_loss: 0.0649
# Epoch 41/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9878 - loss: 0.0512 - val_accuracy: 0.9740 - val_loss: 0.0565
# Epoch 42/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0469 - val_accuracy: 0.9720 - val_loss: 0.0966
# Epoch 43/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0435 - val_accuracy: 0.9800 - val_loss: 0.0592
# Epoch 44/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0350 - val_accuracy: 0.9740 - val_loss: 0.0661
# Epoch 45/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.0353 - val_accuracy: 0.9740 - val_loss: 0.0648
# Epoch 46/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0353 - val_accuracy: 0.9840 - val_loss: 0.0452
# Epoch 47/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0306 - val_accuracy: 0.9760 - val_loss: 0.0560
# Epoch 48/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0293 - val_accuracy: 0.9840 - val_loss: 0.0658
# Epoch 49/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9951 - loss: 0.0281 - val_accuracy: 0.9820 - val_loss: 0.0485
# Epoch 50/50
# 63/63 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0254 - val_accuracy: 0.9820 - val_loss: 0.0624

# %%
# Predict probabilities
y_pred_proba = nn.predict(X_test_scaled)

# Convert probabilities to binary class labels
y_pred = (y_pred_proba > 0.5).astype('int32').flatten()

# Generate and print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Print ROC-AUC score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"ROC-AUC Score: {roc_auc}")
# Out:
# 21/21 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.88      0.89      0.89       540
#            1       0.48      0.47      0.47       119
#
#     accuracy                           0.81       659
#    macro avg       0.68      0.68      0.68       659
# weighted avg       0.81      0.81      0.81       659
#
# ROC-AUC Score: 0.7875194522253347
