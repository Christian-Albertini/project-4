# %% [markdown]
# <a href="https://colab.research.google.com/github/Christian-Albertini/project-4/blob/main/Project_4_with_standings.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report
from sklearn.utils.class_weight import compute_class_weight
from sklearn.metrics import roc_auc_score
from imblearn.over_sampling import SMOTE
import tensorflow as tf
import numpy as np



# Use raw URLs from GitHub
combined_url = 'https://raw.githubusercontent.com/Christian-Albertini/project-4/main/Resources/Merged_Player_Stats.csv'

# Read the CSV files
Combined_Player_Stats = pd.read_csv(combined_url)

# Display the first few rows of each DataFrame
Combined_Player_Stats.head()
# Out:
#             Player  Season  Age Team  Lg    G  AS   PA   AB    R  ...    OPS  \
# 0      Adam Duvall    2023   34  BOS  AL   92   0  353  320   45  ...  0.834
# 1     Adam Frazier    2023   31  BAL  AL  141   0  455  412   59  ...  0.696
# 2  Adley Rutschman    2023   25  BAL  AL  154   1  687  588   84  ...  0.809
# 3    Adolis García    2023   30  TEX  AL  148   1  632  555  108  ...  0.836
# 4      Akil Baddoo    2023   24  DET  AL  112   0  357  312   40  ...  0.682
#
#    OPS+   TB  GIDP  HBP  SH  SF  IBB      Pos  Standings
# 0   119  170     0    6   0   5    1   89/H7D       20.0
# 1    94  163     4    4   4   2    0  *4H/97D        2.0
# 2   128  256    14    2   0   5    6    *2D/H        2.0
# 3   127  282    12    6   0   6    0   *9/8DH        7.0
# 4    88  116     4    0   2   1    2   7H/89D       19.0
#
# [5 rows x 33 columns]

# %%
# Convert categorical data to numeric
combined_df = pd.get_dummies(Combined_Player_Stats, columns=['Lg'])
combined_df=combined_df.drop(columns=['Team', '1B', '2B', '3B', 'CS', 'GIDP','HBP','SH','SF','IBB','Pos'])
combined_df=combined_df.drop(columns=['OPS', 'Age', 'Player'])
combined_df=combined_df.dropna()
# Review Dataframes
combined_df.head()
# Out:
#    Season    G  AS   PA   AB    R    H  HR  RBI  SB  BB   SO     BA    OBP  \
# 0    2023   92   0  353  320   45   79  21   58   4  22  110  0.247  0.303
# 1    2023  141   0  455  412   59   99  13   60  11  32   68  0.240  0.300
# 2    2023  154   1  687  588   84  163  20   80   1  92  101  0.277  0.374
# 3    2023  148   1  632  555  108  136  39  107   9  65  175  0.245  0.328
# 4    2023  112   0  357  312   40   68  11   34  14  42   89  0.218  0.310
#
#      SLG  OPS+   TB  Standings  Lg_AL  Lg_NL
# 0  0.531   119  170       20.0   True  False
# 1  0.396    94  163        2.0   True  False
# 2  0.435   128  256        2.0   True  False
# 3  0.508   127  282        7.0   True  False
# 4  0.372    88  116       19.0   True  False

# %%
# Identify feature and target arrays
combined_df=combined_df.drop(columns=['Lg_AL', 'Lg_NL'])
y = combined_df['AS']
X = combined_df.drop(columns=['AS'])

# Split the data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit and scale the data
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Apply SMOTE to balance the dataset
smote = SMOTE()
X_train_resampled, y_train_resampled = smote.fit_resample(X_train_scaled, y_train)

# %%
# Compute class weights
class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(y_train_resampled),
    y=y_train_resampled
)
class_weight_dict = dict(enumerate(class_weights))

# Define model
number_input_features = len(X_train_resampled[0])
hidden_nodes_layer1 = 30
hidden_nodes_layer2 = 20
hidden_nodes_layer3 = 10

nn = tf.keras.models.Sequential()

# First hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation='relu'))

# Second hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation='sigmoid'))

# Third hidden layer
nn.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation='sigmoid'))

# Output layer
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
# Compile the model
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# Train the model
fit_model = nn.fit(
    X_train_resampled, y_train_resampled,
    epochs=50,
    validation_split=0.2,
    class_weight=class_weight_dict,
    verbose=1
)
# Out:
# Epoch 1/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6084 - loss: 0.6578 - val_accuracy: 0.0000e+00 - val_loss: 0.8871
# Epoch 2/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6555 - loss: 0.5799 - val_accuracy: 0.6296 - val_loss: 0.7330
# Epoch 3/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7863 - loss: 0.5056 - val_accuracy: 0.7222 - val_loss: 0.6825
# Epoch 4/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7831 - loss: 0.4790 - val_accuracy: 0.7551 - val_loss: 0.6325
# Epoch 5/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7926 - loss: 0.4590 - val_accuracy: 0.7819 - val_loss: 0.5767
# Epoch 6/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7755 - loss: 0.4570 - val_accuracy: 0.7840 - val_loss: 0.5766
# Epoch 7/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7945 - loss: 0.4366 - val_accuracy: 0.7881 - val_loss: 0.5745
# Epoch 8/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7784 - loss: 0.4523 - val_accuracy: 0.7881 - val_loss: 0.5553
# Epoch 9/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7821 - loss: 0.4299 - val_accuracy: 0.7840 - val_loss: 0.5498
# Epoch 10/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7929 - loss: 0.4155 - val_accuracy: 0.7942 - val_loss: 0.5230
# Epoch 11/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7943 - loss: 0.4226 - val_accuracy: 0.8025 - val_loss: 0.5128
# Epoch 12/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7806 - loss: 0.4182 - val_accuracy: 0.8333 - val_loss: 0.4702
# Epoch 13/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7964 - loss: 0.4065 - val_accuracy: 0.7963 - val_loss: 0.5188
# Epoch 14/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7905 - loss: 0.3943 - val_accuracy: 0.7922 - val_loss: 0.5054
# Epoch 15/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8075 - loss: 0.3763 - val_accuracy: 0.8045 - val_loss: 0.4742
# Epoch 16/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.7847 - loss: 0.4004 - val_accuracy: 0.7737 - val_loss: 0.5180
# Epoch 17/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8018 - loss: 0.3800 - val_accuracy: 0.7901 - val_loss: 0.4882
# Epoch 18/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.3938 - val_accuracy: 0.7778 - val_loss: 0.4897
# Epoch 19/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8007 - loss: 0.3894 - val_accuracy: 0.8374 - val_loss: 0.4504
# Epoch 20/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8075 - loss: 0.3874 - val_accuracy: 0.8230 - val_loss: 0.4600
# Epoch 21/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8162 - loss: 0.3714 - val_accuracy: 0.7634 - val_loss: 0.5350
# Epoch 22/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8249 - loss: 0.3617 - val_accuracy: 0.7922 - val_loss: 0.4860
# Epoch 23/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8083 - loss: 0.3792 - val_accuracy: 0.7984 - val_loss: 0.4810
# Epoch 24/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8024 - loss: 0.3850 - val_accuracy: 0.8313 - val_loss: 0.4475
# Epoch 25/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8249 - loss: 0.3642 - val_accuracy: 0.7984 - val_loss: 0.4814
# Epoch 26/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8241 - loss: 0.3659 - val_accuracy: 0.7942 - val_loss: 0.4922
# Epoch 27/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8274 - loss: 0.3610 - val_accuracy: 0.8416 - val_loss: 0.4401
# Epoch 28/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8137 - loss: 0.3648 - val_accuracy: 0.8642 - val_loss: 0.4161
# Epoch 29/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8187 - loss: 0.3705 - val_accuracy: 0.8539 - val_loss: 0.4313
# Epoch 30/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8254 - loss: 0.3554 - val_accuracy: 0.8374 - val_loss: 0.4464
# Epoch 31/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8321 - loss: 0.3455 - val_accuracy: 0.8724 - val_loss: 0.4032
# Epoch 32/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8495 - loss: 0.3297 - val_accuracy: 0.8457 - val_loss: 0.4415
# Epoch 33/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8312 - loss: 0.3637 - val_accuracy: 0.8333 - val_loss: 0.4730
# Epoch 34/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8274 - loss: 0.3584 - val_accuracy: 0.8704 - val_loss: 0.4113
# Epoch 35/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.3312 - val_accuracy: 0.8086 - val_loss: 0.5015
# Epoch 36/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8345 - loss: 0.3560 - val_accuracy: 0.8498 - val_loss: 0.4471
# Epoch 37/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8421 - loss: 0.3390 - val_accuracy: 0.8827 - val_loss: 0.3941
# Epoch 38/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8479 - loss: 0.3394 - val_accuracy: 0.8333 - val_loss: 0.4801
# Epoch 39/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8271 - loss: 0.3593 - val_accuracy: 0.8374 - val_loss: 0.4631
# Epoch 40/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8450 - loss: 0.3285 - val_accuracy: 0.8333 - val_loss: 0.4618
# Epoch 41/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8511 - loss: 0.3260 - val_accuracy: 0.8560 - val_loss: 0.4303
# Epoch 42/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8417 - loss: 0.3471 - val_accuracy: 0.8333 - val_loss: 0.4763
# Epoch 43/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8334 - loss: 0.3352 - val_accuracy: 0.8704 - val_loss: 0.4092
# Epoch 44/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8335 - loss: 0.3479 - val_accuracy: 0.8560 - val_loss: 0.4506
# Epoch 45/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8416 - loss: 0.3377 - val_accuracy: 0.8642 - val_loss: 0.4197
# Epoch 46/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8485 - loss: 0.3252 - val_accuracy: 0.8601 - val_loss: 0.4341
# Epoch 47/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8436 - loss: 0.3345 - val_accuracy: 0.8889 - val_loss: 0.3645
# Epoch 48/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8645 - loss: 0.3101 - val_accuracy: 0.8786 - val_loss: 0.3873
# Epoch 49/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.8474 - loss: 0.3285 - val_accuracy: 0.8786 - val_loss: 0.3835
# Epoch 50/50
# 61/61 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8502 - loss: 0.3264 - val_accuracy: 0.8313 - val_loss: 0.4793

# %%
# Predict probabilities
y_pred_proba = nn.predict(X_test_scaled)

# Convert probabilities to binary class labels
y_pred = (y_pred_proba > 0.5).astype('int32').flatten()

# Generate and print classification report
print("Classification Report:")
print(classification_report(y_test, y_pred))

# Print ROC-AUC score
roc_auc = roc_auc_score(y_test, y_pred_proba)
print(f"ROC-AUC Score: {roc_auc}")
# Out:
# 20/20 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.88       516
#            1       0.50      0.71      0.59       121
#
#     accuracy                           0.81       637
#    macro avg       0.71      0.77      0.73       637
# weighted avg       0.84      0.81      0.82       637
#
# ROC-AUC Score: 0.8551316548145301
